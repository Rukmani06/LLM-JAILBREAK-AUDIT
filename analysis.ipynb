# %%
import pandas as pd
import matplotlib.pyplot as pyplt 
import seaborn as sns 
#load results
df= pd.read_csv('results/responses.csv') 
#quick look at data
print(f"Total respomses: {len(df)}")
print(f"Models tested:{df['model'].unique()}")
print(f"categories tested: {df['category'].unique()}")
df.head()
